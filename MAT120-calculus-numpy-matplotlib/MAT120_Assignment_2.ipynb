# %%
#Task 1

from sympy import*
x, a, b = symbols("x a b")
f= sin(a*x)*exp(-b*x)
integrate(f, x)
# Out:
# Piecewise((0, Eq(a, 0) & Eq(b, 0)), (-I*(x*exp(-b*x)*sinh(b*x)/2 + x*exp(-b*x)*cosh(b*x)/2 + exp(-b*x)*cosh(b*x)/(2*b)), Eq(a, -I*b)), (I*(x*exp(-b*x)*sinh(b*x)/2 + x*exp(-b*x)*cosh(b*x)/2 + exp(-b*x)*cosh(b*x)/(2*b)), Eq(a, I*b)), (-a*cos(a*x)/(a**2*exp(b*x) + b**2*exp(b*x)) - b*sin(a*x)/(a**2*exp(b*x) + b**2*exp(b*x)), True))

# %%
#Task 2
import sympy as smp
import numpy as np
import scipy as sp
from scipy.integrate import quad
f = lambda x: ((np.arcsin(2*x)/(1 + x**2)
x = smp.symbols("x")
var = smp.asin(2*x)
f = var/(1 + x**2)
smp.integrate(f, (x, 0, oo)).evalf()
# Out:
#   File "<ipython-input-3-2cdcf684b79c>", line 7
#     var = asin(2*x)
#     ^
# SyntaxError: invalid syntax

# %%
#Task 3

import numpy as np
import scipy as sp
from scipy.integrate import quad
a = 2
b = 4
f = lambda x: 1/((a-cos(x))**2 + (b-sin(x))**2)
quad(f, 0, 2*np.pi)
# Out:
# (0.3306939635357684, 1.3538220736521514e-09)

# %%
#Task 4

import sympy as spy
import numpy as np
import scipy as sp
from scipy.integrate import quad
x = spy.symbols("x")
y= spy.acos(2*x)
f = y/(1+x**2)
spy.integrate(f,(x,0,spy.oo)).evalf()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1323     try:
# -> 1324         rf = evalf_table[x.func]
#    1325         r = rf(x, prec, options)
#
# KeyError: acos
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-e22291ec1f19> in <module>
#       7 var = spy.acos(2*x)
#       8 f = var/(1+x**2)
# ----> 9 spy.integrate(f,(x,0,spy.oo)).evalf()
#
# /usr/local/lib/python3.7/dist-packages/sympy/core/evalf.py in evalf(self, n, subs, maxn, chop, strict, quad, verbose)
#    1471             options['quad'] = quad
#    1472         try:
# -> 1473             result = evalf(self, prec + 4, options)
#    1474         except NotImplementedError:
# ...

# %%
#Task 5
from sympy import*

x = symbols("x")
f = x*exp(6*x)
integrate(f, (x, -1, 2)).evalf()
# Out:
# 49730.6311933419
